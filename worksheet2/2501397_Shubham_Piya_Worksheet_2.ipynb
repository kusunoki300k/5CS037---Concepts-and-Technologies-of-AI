# %% [markdown]
# 3.1 Problem 1

# %%
# 1

import pandas as pd
import os
bank_path = "bank.csv"
bank_df = pd.read_csv(bank_path)
bank_df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
# 2

# a
print(df_bank.info())
column_objects = bank_df.select_dtypes(include="object").columns.tolist()
print("\nColumns with dtypes=object:", column_objects)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
#
# ...

# %%
# b
for cols in column_objects:
    unique = bank_df[cols].unique()
    print(f"\nFound {len(unique)} unique values in {cols}:")
    print(unique)
# Out:
# Found 12 unique values in job:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# Found 3 unique values in marital:
# ['married' 'single' 'divorced']
#
# Found 4 unique values in education:
# ['tertiary' 'secondary' 'unknown' 'primary']
#
# Found 2 unique values in default:
# ['no' 'yes']
#
# Found 2 unique values in housing:
# ['yes' 'no']
#
# Found 2 unique values in loan:
# ['no' 'yes']
#
# Found 3 unique values in contact:
# ['unknown' 'cellular' 'telephone']
#
# Found 12 unique values in month:
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# Found 4 unique values in poutcome:
# ['unknown' 'failure' 'other' 'success']
#
# Found 2 unique values in y:
# ['no' 'yes']

# %%
# c
print("Total number of null values in each column:")
print(bank_df.isnull().sum())
# Out:
# Total number of null values in each column:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# 3

numeric_only_df = bank_df.select_dtypes(exclude="object")
numeric_only_df.to_csv("banknumericdata.csv", index=False)
numeric_only_df
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 0       58     2143    5       261         1     -1         0
# 1       44       29    5       151         1     -1         0
# 2       33        2    5        76         1     -1         0
# 3       47     1506    5        92         1     -1         0
# 4       33        1    5       198         1     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 45206   51      825   17       977         3     -1         0
# 45207   71     1729   17       456         2     -1         0
# 45208   72     5715   17      1127         5    184         3
# 45209   57      668   17       508         4     -1         0
# 45210   37     2971   17       361         2    188        11
#
# [45211 rows x 7 columns]

# %%
# 4

bank_numeric = pd.read_csv("banknumericdata.csv")
print("Summary statistics:")
print(bank_numeric.describe())
# Out:
# Summary statistics:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# 3.1 Problem 2

# %%
# 1

medical_file_path = "medical_students_dataset.csv"
med_df = pd.read_csv(medical_file_path)
med_df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
# 2

print(med_df.info())
null_columns = med_df.columns[med_df.isnull().any()].tolist()
print("\nColumns with missing values:")
print(null_columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
# None
#
# Columns with missing values:
# ...

# %%
# 3

mean_fill_cols = ['Age', 'Height', 'Weight', 'BMI', 'Temperature', 'Heart Rate']
for col in mean_fill_cols:
    med_df[col] = med_df[col].fillna(med_df[col].mean())

median_fill_cols = ['Cholesterol', 'Blood Pressure']
for col in median_fill_cols:
    med_df[col] = med_df[col].fillna(med_df[col].median())

mode_fill_cols = ['Gender', 'Blood Type', 'Diabetes', 'Smoking']
for col in mode_fill_cols:
    med_df[col] = med_df[col].fillna(med_df[col].mode()[0])

# %% [markdown]
# Explanation:
#
# I. Mean fill:
#    The numerical columns Age, Height, Weight, BMI, Temperature and Heart Rate have continuous values and symmetric distributions hence mean fill is used.
#
# II. Median fill:
#     The numerical columns Cholesterol and Blood Pressure have skewed distributions hence median fill is used.
#
# III. Mode fill:
#      The columns Gender, Blood Type, Diabetes and Smoking are categorical in nature hence mode fill is used to fill in the null spaces with the most common category.

# %%
# 4

num_duplicate = med_df.duplicated().sum()
print("Duplicate rows count:", num_duplicate)
if num_duplicate > 0:
    duplicate_removed = med_df.drop_duplicates()
    print("Dropped duplicates.")
else:
    print("No duplicates found.")
# Out:
# Duplicate rows count: 7644
# Dropped duplicates.

# %% [markdown]
# 3.2

# %%
# Problem 1

titanic_path = "Titanic-Dataset.csv"
df = pd.read_csv(titanic_path)

subset = df[['Name','Pclass','Sex','Age','Fare','Survived']]
first_class = subset[subset['Pclass'] == 1]

fare_mean = first_class['Fare'].mean()
fare_median = first_class['Fare'].median()
fare_max = first_class['Fare'].max()
fare_min = first_class['Fare'].min()

fare_mean, fare_median, fare_max, fare_min
# Out:
# (np.float64(84.1546875),
#  np.float64(60.287499999999994),
#  np.float64(512.3292),
#  np.float64(0.0))

# %%
# Problem 2

age_nulls = first_class['Age'].isnull().sum()
print(f"Found {age_nulls.item()} null values")

first_class_no_age_na = first_class.dropna(subset=['Age'])
# Out:
# Found 30 null values

# %%
# Problem 3

# Task 1
df2 = df.copy()
embarked_dummies = pd.get_dummies(df2['Embarked'], prefix='Embarked', dtype=int)

# Task 2
df2 = pd.concat([df2, embarked_dummies], axis=1)

# Task 3
df2 = df2.drop(columns=['Embarked'])

# Task 4
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN           0           0           1
# 1      0          PC 17599  71.2833   C85           1           0           0
# 2      0  STON/O2. 3101282   7.9250   NaN           0           0           1
# ...

# %%
# Problem 4

survival_by_sex = df.groupby('Sex')['Survived'].mean()
survival_by_sex.plot(kind='bar')
survival_by_sex
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Problem 5

surv_by_emb_sex = df.groupby(['Embarked','Sex'])['Survived'].mean().unstack()
surv_by_emb_sex.plot(kind='bar')
surv_by_emb_sex
# Out:
# Sex         female      male
# Embarked
# C         0.876712  0.305263
# Q         0.750000  0.073171
# S         0.689655  0.174603
